# %%
import pdf_converter

# %%
urls = [
    "https://docs.myaltimate.com/#features",
    "https://docs.myaltimate.com/setup/installation/",
    "https://docs.myaltimate.com/setup/reqdConfig/",
    "https://docs.myaltimate.com/setup/optConfig/",
    "https://docs.myaltimate.com/setup/faq/",
    "https://docs.myaltimate.com/develop/autocomplete/",
    "https://docs.myaltimate.com/develop/clicktorun/",
    "https://docs.myaltimate.com/develop/compiledCode/",
    "https://docs.myaltimate.com/develop/genmodelSource/",
    "https://docs.myaltimate.com/develop/genmodelSQL/",
    "https://docs.myaltimate.com/test/sqlvalidation/",
    "https://docs.myaltimate.com/develop/explanation/",
    "https://docs.myaltimate.com/develop/updatemodel/",
    "https://docs.myaltimate.com/develop/translateSQL/",
    "https://docs.myaltimate.com/test/queryResults/",
    "https://docs.myaltimate.com/test/adhocquery/",
    "https://docs.myaltimate.com/test/sqlvisualizer/",
    "https://docs.myaltimate.com/test/writetests/",
    "https://docs.myaltimate.com/test/runtests/",
    "https://docs.myaltimate.com/test/lineage/",
    "https://docs.myaltimate.com/test/defertoprod/",
    "https://docs.myaltimate.com/document/write/",
    "https://docs.myaltimate.com/document/generatedoc/",
    "https://docs.myaltimate.com/govern/governance/",
    "https://docs.myaltimate.com/govern/multiproject/",
    "https://docs.myaltimate.com/govern/querybookmarks/",
    "https://docs.myaltimate.com/discover/setupui/",
    "https://docs.myaltimate.com/discover/viewdocs/",
    "https://docs.myaltimate.com/discover/viewlineage/",
    "https://docs.myaltimate.com/test/bigquerycost/",
    "https://docs.myaltimate.com/test/utilities/",
    "https://docs.myaltimate.com/arch/faq/",
    "https://docs.myaltimate.com/arch/pricingfaq/",
    "https://docs.myaltimate.com/trobleshooting/"
]

# %%
urls = []

# %%
pdf_converter.save_other_webpages_as_pdfs(urls=urls,
    destination="best-practices")
# Out:
# Processing https://docs.myaltimate.com/#features
# Processing https://docs.myaltimate.com/setup/installation/
# Processing https://docs.myaltimate.com/setup/reqdConfig/
# Processing https://docs.myaltimate.com/setup/optConfig/
# Response time for https://docs.myaltimate.com/setup/installation/: 0.078189 seconds
# Response time for https://docs.myaltimate.com/#features: 0.076316 seconds
# Response time for https://docs.myaltimate.com/setup/reqdConfig/: 0.078467 seconds
# Response time for https://docs.myaltimate.com/setup/optConfig/: 0.071575 seconds
# Saved: KnowledgeBase/dbt-extension-docs/.pdf
# Processing https://docs.myaltimate.com/setup/faq/
# Response time for https://docs.myaltimate.com/setup/faq/: 0.057902 seconds
# Saved: KnowledgeBase/dbt-extension-docs/setup-optConfig.pdf
# Processing https://docs.myaltimate.com/develop/autocomplete/
# Response time for https://docs.myaltimate.com/develop/autocomplete/: 0.06583 seconds
# ...
